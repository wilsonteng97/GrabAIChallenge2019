# %% [markdown]
# # Background:
# According to the World Health Organization, approximately 1.35 million people die as a result of a road traffic crash every year. Between 20 and 50 million more suffer non-fatal injuries, with many incurring a disability as a result of their injury.
#
# Road traffic injuries cause considerable economic losses to individuals, their families, and to nations as a whole. These losses arise from the cost of treatment as well as lost productivity for those killed or disabled by their injuries, and for family members who need to take time off work or school to care for the injured. Road traffic crashes cost most countries 3% of their gross domestic product.
#
# In my project, I will derive a classification model primarily through feature engineering to detect dangerous driving trips using time-series telemetry data from Grab. This model will be evaluated based on the AUC-ROC curve.
#
# ##### Dataset Obtained from (https://s3-ap-southeast-1.amazonaws.com/grab-aiforsea-dataset/safety.zip)

# %% [markdown]
# _______
# # Dataset characteristics:
#
# Dataset is a time-series of the following features for every "bookingID"
#
# |Datapoint:     | Description:                                               |
# | ------------- |:-------------:                                             |
# |bookingID      |trip id                                                     |
# |Label          |1 indicates dangerous driving & 0 indicates safe driving    |
#
# |Features (time-series):     | Description:                          |
# | -------------              |:-------------:                        |
# |Accuracy                    |accuracy inferred by GPS in meters     |
# |Bearing                     |GPS bearing in degree                  |
# |acceleration_x              |accelerometer reading at x axis (m/s2) |
# |acceleration_y              |accelerometer reading at y axis (m/s2) |
# |acceleration_z              |accelerometer reading at z axis (m/s2) |
# |gyro_x                      |gyroscope reading in x axis (rad/s)    |
# |gyro_y                      |gyroscope reading in y axis (rad/s)    |
# |gyro_z                      |gyroscope reading in z axis (rad/s)    |
# |second                      |time of the record by number of seconds|
# |Speed                       |speed measured by GPS in m/s           |

# %% [markdown]
# ____
# # Engineered Features:
# Features are decided upon primarily through domain knowledge and analysis of correlation with label using a pairplot.
#
# |Engineered Features (Datapoint):|Description: |
# | -------------                  |---|
# |Accuracy                        |Median Accuracy value with respect to range of timeseries data. If Median Accuracy is not available, Min Accuracy value is used instead
# |Bearing_delta                   |Standard Deviation of the difference between each timeseries datapoint
# |acceleration_x                  |Number of threshold crossovers with threshold set at 0
# |acceleration_y                  |Number of threshold crossovers with threshold set at Mean of acceleration_y
# |acceleration_z                  |Number of threshold crossovers with threshold set at Mean of acceleration_z
# |gyro_x                          |Max gyro_x value - Min gyro_z value
# |gyro_y                          |Max gyro_y value - Min gyro_z value
# |gyro_z                          |Max gyro_z value - Min gyro_z value
# |Speed                           |Mean of Speed in timeseries data
# |missing_rng                     |Number of missing values in the range of timeseries data

# %%
import pandas as pd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
import matplotlib.pyplot as plt
from pprint import pprint
sns.set()
from pathlib import Path

# %%
import tensorflow as tf
from sklearn.metrics import roc_auc_score
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier

from sklearn.model_selection import train_test_split
from keras.models import load_model

# from sklearn.datasets import make_classification
# from sklearn.preprocessing import label_binarize
# Out:
# Using TensorFlow backend.

# %%
df_features = pd.read_csv('safety/data_cleaned_features.csv')

df_labels = pd.read_csv('safety/data_cleaned_labels.csv')

df_combined = pd.read_csv('safety/data_cleaned_combined.csv')

df_engineered_features = pd.read_csv('safety/engineered_features.csv')

# %%
# sns.pairplot(df_engineered_features, hue='label')
df_engineered_features_combined = df_engineered_features.set_index('ID').join(df_labels.set_index('bookingID'))
df_engineered_features_combined.head(10)
# Out:
#     Accuracy  Bearing_delta  acceleration_x  acceleration_y  acceleration_z  \
# ID
# 0      4.000      24.884408           840.0           881.0           762.0
# 1      3.474       9.901822           739.0           105.0           537.0
# 2      3.000      40.149162            58.0             9.0            69.0
# 4     10.000      18.359159           921.0           957.0           908.0
# 6      4.050      18.636297           210.0           181.0           306.0
# 7      3.000      18.295717            73.0           250.0           419.0
# 8      5.059      27.750184           370.0            55.0            70.0
# 10     4.996      26.617731            54.0           102.0           298.0
# 11     3.000      24.222294            59.0            27.0            68.0
# 14    32.000      10.382653           428.0           578.0           222.0
#
#       gyro_x    gyro_y    gyro_z      Speed  missing_rng  label
# ID
# 0   0.830909  1.079655  1.104699   9.004787        588.0      0
# 1   0.251903  1.149020  0.356396   8.019369        198.0      1
# 2   0.437379  0.893696  0.381791   3.157213        632.0      1
# 4   0.859239  1.159158  0.853409   6.150996          2.0      1
# 6   0.615752  1.153924  0.712880   4.628921          1.0      0
# 7   1.339190  0.950630  1.385622  12.176386         12.0      0
# 8   0.564484  0.747498  0.158203   5.384260         79.0      0
# 10  0.537964  0.929550  0.394135   8.702027          1.0      0
# 11  1.158811  1.010982  0.532674   6.659024         76.0      0
# 14  1.440351  0.961935  0.710777   4.744597          3.0      0

# %% [markdown]
# # Pairplot of Engineered Features

# %%
sns.pairplot(df_engineered_features_combined, hue='label')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
features_col=['Accuracy', 'Bearing_delta', 
              'acceleration_x', 'acceleration_y', 'acceleration_z', 
              'gyro_x', 'gyro_y', 'gyro_z', 
              'Speed', 'missing_rng']

# %%
# Percentage of safe driving labels
100 - len(df_labels[df_labels['label']==1])/len(df_labels) *100
# Out:
# 75.10273629347499

# %%
df_combined.head()
# Out:
#    bookingID  Accuracy     Bearing  acceleration_x  acceleration_y  \
# 0          0      12.0  143.298294        0.818112       -9.941461
# 1          0       8.0  143.298294        0.546405       -9.835590
# 2          0       8.0  143.298294       -1.706207       -9.270792
# 3          0       8.0  143.298294       -1.416705       -9.548032
# 4          0       8.0  143.298294       -0.598145       -9.853534
#
#    acceleration_z    gyro_x    gyro_y    gyro_z  second     Speed  label
# 0       -2.014999 -0.016245 -0.094040  0.070732     0.0  3.442991      0
# 1       -2.038925 -0.047092 -0.078874  0.043187     1.0  0.228454      0
# 2       -1.209448 -0.028965 -0.032652  0.015390     2.0  0.228454      0
# 3       -1.860977 -0.022413  0.005049 -0.025753     3.0  0.228454      0
# 4       -1.378574 -0.014297 -0.046206  0.021902     4.0  0.228454      0

# %%
# Convert bookingIDs to dataframe
def convert_to_df(ids, dataset):
    return dataset.loc[dataset['bookingID']==ids].reset_index(drop=True)

def graph_bookingID(ID):
    bookingid = df_combined.loc[df_combined['bookingID']==ID]
    label = 'BookingID ' + str(ID) + ' (Label ' + str(bookingid['label'].iloc[0]) + ')'
    bookingid = bookingid.drop(['bookingID'],axis=1)
    print(bookingid.describe())


    accuracy = bookingid.loc[:, ['Accuracy', 'second']]
    acceleration_all = bookingid.loc[:, ['acceleration_x', 'acceleration_y', 'acceleration_z', 'second']]
    gyro_all = bookingid.loc[:, ['gyro_x', 'gyro_y', 'gyro_z', 'second']]
    speed = bookingid.loc[:, ['Speed', 'second']]
    
    f, axes = plt.subplots(4, 1, figsize=(20,20))
    graphs = [accuracy, acceleration_all, gyro_all, speed]

    count=0
    for g in graphs:
        g.plot(x='second', ax=axes[count])
        count +=1
    axes[0].set_title(label, fontsize=16)

# %%
print(df_combined.shape)
print(df_combined.dtypes)
# Out:
# (15876649, 12)
# bookingID           int64
# Accuracy          float64
# Bearing           float64
# acceleration_x    float64
# acceleration_y    float64
# acceleration_z    float64
# gyro_x            float64
# gyro_y            float64
# gyro_z            float64
# second            float64
# Speed             float64
# label               int64
# dtype: object

# %%
convert_to_df(0, df_combined).describe()
# Out:
#        bookingID     Accuracy      Bearing  acceleration_x  acceleration_y  \
# count     1003.0  1003.000000  1003.000000     1003.000000     1003.000000
# mean         0.0    10.127617   176.419864       -0.708812       -9.613829
# std          0.0     3.667800   129.251952        0.925227        0.640254
# min          0.0     4.000000     0.037464       -4.692294      -12.764703
# 25%          0.0     8.000000    38.211140       -1.184251       -9.904376
# 50%          0.0     8.000000   144.299423       -0.724802       -9.623547
# 75%          0.0    12.000000   312.108078       -0.297726       -9.342868
# max          0.0    32.000000   359.979767        4.782614       -6.119916
#
#        acceleration_z       gyro_x       gyro_y       gyro_z       second  \
# count     1003.000000  1003.000000  1003.000000  1003.000000  1003.000000
# mean        -1.622308     0.003403    -0.006175    -0.004107   903.231306
# std          1.138741     0.065944     0.100259     0.063666   533.929149
# min         -6.251807    -0.392537    -0.609930    -0.731892     0.000000
# 25%         -2.250594    -0.027035    -0.046184    -0.029853   250.500000
# 50%         -1.608112     0.002603    -0.002345    -0.003478  1087.000000
# 75%         -1.035463     0.033266     0.032592     0.020898  1338.500000
# max          2.318857     0.438371     0.469724     0.372807  1589.000000
#
#              Speed   label
# count  1003.000000  1003.0
# mean      9.004787     0.0
# std       7.196581     0.0
# min       0.064309     0.0
# 25%       1.601906     0.0
# 50%       8.522352     0.0
# 75%      15.647217     0.0
# max      22.946083     0.0

# %%
print(len(df_combined['bookingID'].unique().tolist()))
df1 = df_combined.dropna()
print(len(df1['bookingID'].unique().tolist()))
# Out:
# 19954
# 19954

# %%
print(len(df_labels['bookingID'].unique().tolist()))
df1_labels = df_labels.dropna()
print(len(df1_labels['bookingID'].unique().tolist()))
# Out:
# 19954
# 19954

# %% [markdown]
# # Getting X data

# %%
from sklearn import preprocessing
print(df_engineered_features.shape)
X = df_engineered_features[features_col].values
# X = preprocessing.normalize(X)
X
# Out:
# (19954, 11)
# array([[4.00000000e+00, 2.48844083e+01, 8.40000000e+02, ...,
#         1.10469893e+00, 9.00478686e+00, 5.88000000e+02],
#        [3.47400000e+00, 9.90182162e+00, 7.39000000e+02, ...,
#         3.56396240e-01, 8.01936901e+00, 1.98000000e+02],
#        [3.00000000e+00, 4.01491622e+01, 5.80000000e+01, ...,
#         3.81790760e-01, 3.15721296e+00, 6.32000000e+02],
#        ...,
#        [1.07200000e+01, 3.36120291e+01, 4.94000000e+02, ...,
#         5.37963860e-01, 1.27187051e+01, 2.11000000e+02],
#        [3.90000000e+00, 1.13974256e+01, 3.69000000e+02, ...,
#         1.45080490e+00, 6.25246678e+00, 5.00000000e+00],
#        [5.70000000e+01, 2.80265299e+01, 3.12000000e+02, ...,
#         4.67942437e-01, 5.20050627e+00, 1.87000000e+02]])

# %%
# demonstrate data normalization with sklearn
from sklearn.preprocessing import MinMaxScaler, StandardScaler
sc = StandardScaler()
X = sc.fit_transform(X)
X
# Out:
# array([[-3.33975023e-01,  2.20518381e-01,  1.47244252e+00, ...,
#          6.56919586e-03,  1.02718073e-01,  2.33931983e+00],
#        [-4.07783003e-01, -1.03776183e+00,  1.15340008e+00, ...,
#         -3.04756122e-01, -1.25337566e-01,  3.86373688e-01],
#        [-4.74294375e-01,  1.50249579e+00, -9.97767320e-01, ...,
#         -2.94190936e-01, -1.25058825e+00,  2.55965222e+00],
#        ...,
#        [ 6.08971022e-01,  9.53488775e-01,  3.79485227e-01, ...,
#         -2.29216373e-01,  9.62231633e-01,  4.51471893e-01],
#        [-3.48006959e-01, -9.12156759e-01, -1.53692875e-02, ...,
#          1.50563803e-01, -5.34252443e-01, -5.80084275e-01],
#        [ 7.10295063e+00,  4.84402681e-01, -1.95422946e-01, ...,
#         -2.58348223e-01, -7.77708076e-01,  3.31290592e-01]])

# %% [markdown]
# # Getting y data

# %%
print(df_labels.shape)
y = list(df_labels['label'])
y = np.array(y)
print(y)
# Out:
# (19954, 2)
# [0 1 1 ... 1 1 1]

# %%
n_classes = 2
n_samples=len(df_combined['bookingID'].unique().tolist())

# X, y = make_classification(n_samples=n_samples, n_features=9, n_informative=3, n_redundant=2, n_classes=n_classes,
#     n_clusters_per_class=2)
# Binarize the output
# y = label_binarize(y, classes=[0, 1])

n_classes = len(y)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
print(len(y_train))
np.bincount(y_train)
# print(list(y_train))
# Out:
# 15963
# array([12002,  3961], dtype=int64)

# %% [markdown]
# ### Implementing Cyclic Learning Rate:
# (Credits: https://github.com/bckenstler/CLR)

# %%
from keras.callbacks import *

class CyclicLR(Callback):
    """This callback implements a cyclical learning rate policy (CLR).
    The method cycles the learning rate between two boundaries with
    some constant frequency, as detailed in this paper (https://arxiv.org/abs/1506.01186).
    The amplitude of the cycle can be scaled on a per-iteration or 
    per-cycle basis.
    This class has three built-in policies, as put forth in the paper.
    "triangular":
        A basic triangular cycle w/ no amplitude scaling.
    "triangular2":
        A basic triangular cycle that scales initial amplitude by half each cycle.
    "exp_range":
        A cycle that scales initial amplitude by gamma**(cycle iterations) at each 
        cycle iteration.
    For more detail, please see paper.
    
    # Example
        ```python
            clr = CyclicLR(base_lr=0.001, max_lr=0.006,
                                step_size=2000., mode='triangular')
            model.fit(X_train, Y_train, callbacks=[clr])
        ```
    
    Class also supports custom scaling functions:
        ```python
            clr_fn = lambda x: 0.5*(1+np.sin(x*np.pi/2.))
            clr = CyclicLR(base_lr=0.001, max_lr=0.006,
                                step_size=2000., scale_fn=clr_fn,
                                scale_mode='cycle')
            model.fit(X_train, Y_train, callbacks=[clr])
        ```    
    # Arguments
        base_lr: initial learning rate which is the
            lower boundary in the cycle.
        max_lr: upper boundary in the cycle. Functionally,
            it defines the cycle amplitude (max_lr - base_lr).
            The lr at any cycle is the sum of base_lr
            and some scaling of the amplitude; therefore 
            max_lr may not actually be reached depending on
            scaling function.
        step_size: number of training iterations per
            half cycle. Authors suggest setting step_size
            2-8 x training iterations in epoch.
        mode: one of {triangular, triangular2, exp_range}.
            Default 'triangular'.
            Values correspond to policies detailed above.
            If scale_fn is not None, this argument is ignored.
        gamma: constant in 'exp_range' scaling function:
            gamma**(cycle iterations)
        scale_fn: Custom scaling policy defined by a single
            argument lambda function, where 
            0 <= scale_fn(x) <= 1 for all x >= 0.
            mode paramater is ignored 
        scale_mode: {'cycle', 'iterations'}.
            Defines whether scale_fn is evaluated on 
            cycle number or cycle iterations (training
            iterations since start of cycle). Default is 'cycle'.
    """

    def __init__(self, base_lr=0.001, max_lr=0.006, step_size=2000., mode='triangular',
                 gamma=1., scale_fn=None, scale_mode='cycle'):
        super(CyclicLR, self).__init__()

        self.base_lr = base_lr
        self.max_lr = max_lr
        self.step_size = step_size
        self.mode = mode
        self.gamma = gamma
        if scale_fn == None:
            if self.mode == 'triangular':
                self.scale_fn = lambda x: 1.
                self.scale_mode = 'cycle'
            elif self.mode == 'triangular2':
                self.scale_fn = lambda x: 1/(2.**(x-1))
                self.scale_mode = 'cycle'
            elif self.mode == 'exp_range':
                self.scale_fn = lambda x: gamma**(x)
                self.scale_mode = 'iterations'
        else:
            self.scale_fn = scale_fn
            self.scale_mode = scale_mode
        self.clr_iterations = 0.
        self.trn_iterations = 0.
        self.history = {}

        self._reset()

    def _reset(self, new_base_lr=None, new_max_lr=None,
               new_step_size=None):
        """Resets cycle iterations.
        Optional boundary/step size adjustment.
        """
        if new_base_lr != None:
            self.base_lr = new_base_lr
        if new_max_lr != None:
            self.max_lr = new_max_lr
        if new_step_size != None:
            self.step_size = new_step_size
        self.clr_iterations = 0.
        
    def clr(self):
        cycle = np.floor(1+self.clr_iterations/(2*self.step_size))
        x = np.abs(self.clr_iterations/self.step_size - 2*cycle + 1)
        if self.scale_mode == 'cycle':
            return self.base_lr + (self.max_lr-self.base_lr)*np.maximum(0, (1-x))*self.scale_fn(cycle)
        else:
            return self.base_lr + (self.max_lr-self.base_lr)*np.maximum(0, (1-x))*self.scale_fn(self.clr_iterations)
        
    def on_train_begin(self, logs={}):
        logs = logs or {}

        if self.clr_iterations == 0:
            K.set_value(self.model.optimizer.lr, self.base_lr)
        else:
            K.set_value(self.model.optimizer.lr, self.clr())        
            
    def on_batch_end(self, epoch, logs=None):
        
        logs = logs or {}
        self.trn_iterations += 1
        self.clr_iterations += 1

        self.history.setdefault('lr', []).append(K.get_value(self.model.optimizer.lr))
        self.history.setdefault('iterations', []).append(self.trn_iterations)

        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)
        
        K.set_value(self.model.optimizer.lr, self.clr())

# %%
from keras import backend as K  

# Metric Functions
def auroc(y_true, y_pred):
    return tf.py_func(roc_auc_score, (y_true, y_pred), tf.double)

def precision(y_true, y_pred):
    '''Calculates the precision, a metric for multi-label classification of
    how many selected items are relevant.
    '''
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def recall(y_true, y_pred):
    '''Calculates the recall, a metric for multi-label classification of
    how many relevant items are selected.
    '''
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

# %% [markdown]
# # Model Architecture

# %%
from keras.optimizers import Adam, SGD, RMSprop

# Using triangular learning rate policy
# base_lr (which is the lower boundary in the cycle) is 00009
clr_triangular = CyclicLR(mode='triangular')

adam = Adam(lr=0.00009, decay=0.0008)
# adam = SGD(lr=0.0001, decay=0.0008, momentum=0.9)

# %%
# from sklearn.linear_model import LogisticRegression
from keras.layers import Input, Conv1D, Dense, MaxPool1D, Activation, Dropout
from keras.models import Model, Sequential
classifier = Sequential()
#Input Layer
classifier.add(Dense(32, activation='relu', kernel_initializer='random_normal', input_dim=len(features_col)))
classifier.add(Dropout(0.15))
classifier.add(Dense(16, activation='relu', kernel_initializer='random_normal'))
classifier.add(Dense(8, activation='relu', kernel_initializer='random_normal'))
classifier.add(Dense(4, activation='relu', kernel_initializer='random_normal'))

#Output Layer
classifier.add(Dense(1, activation='sigmoid', kernel_initializer='random_normal'))

#Compile Model
classifier.compile(optimizer=adam, loss='binary_crossentropy', metrics =['accuracy', precision, recall, auroc])

# %%
from keras.callbacks import ModelCheckpoint

bestValidationCheckpointer = ModelCheckpoint('train_model.h5', monitor='val_auroc', save_best_only=True, verbose=0)

# %% [markdown]
# # Stratefied K-Fold Cross Validation
#
# Methodology (For each Fold):
# 1. Upsample Label 1 of X_train/y_train to ratio of 0.7 of Label 0
# 2. Downsample Label 0 of X_train/y_train to get balanced labels for train data
# 3. Fit Classfier using new Train Data (Triangular Learning Rate)
# 4. Append hist to history for tracking

# %%
# Import Dependencies
from sklearn.model_selection import StratifiedKFold
from imblearn.over_sampling import SMOTE 
import random
import timeit

from sklearn.metrics import roc_curve
from sklearn.metrics import auc
from sklearn.metrics import confusion_matrix

# %%
# Initialise Model Parameters
epochs = 75
bs = 32 
validation_data=(X_test, y_test)

# Keep track of model history
history = []
auc_score = []
TrainSet_ConfusionMatrix = []
TestSet_ConfusionMatrix = []
fpr_and_tpr = []

# Stratified K-Fold Cross Validation 
skf = StratifiedKFold(n_splits=5, random_state=None)
foldcount=0
for train_index, test_index in skf.split(X,y):
    print("K-Fold ", str(foldcount), ":")
    print("Train:", train_index, "Validation:", test_index) 
    
    # Initial Train & Test set for current fold 
    X_train, X_test, y_train, y_test = X[train_index], X[test_index], y[train_index], y[test_index]
    
    # Upsampling using SMOTE
    sm = SMOTE(random_state=12, ratio=0.7)
    x_res, y_res = sm.fit_sample(X_train, y_train)

    # Downsampling
    # Indicies of each class' observations
    i_class0 = np.where(y_res == 0)[0]
    i_class1 = np.where(y_res == 1)[0]
    # Number of observations in each class
    n_class0 = len(i_class0)
    n_class1 = len(i_class1)
    # For every observation of class 0, randomly sample from class 1 without replacement
    i_class1_downsampled = np.random.choice(i_class0, size=n_class1, replace=False)
    new_y_res_idx = list(i_class1_downsampled) + list(i_class1)
    for i in range(3):
        random.shuffle(new_y_res_idx)
        
    # New train data after upsampling of label 1 class & downsampling of label 0 class
    X_train = x_res[new_y_res_idx]
    y_train = y_res[new_y_res_idx]
    print(len(X_train))
    print(len(y_train))
    print(np.bincount(y_train), '\n') # balanced dataset
    
    # Start Time
    startTime = timeit.default_timer()

    # Fit Model
    hist = classifier.fit(X_train, y_train,
                             epochs=epochs, batch_size=bs, verbose=1, 
                             validation_data=validation_data,
                             callbacks=[clr_triangular])
    
    # End Time 
    elapsedTime = timeit.default_timer() - startTime
    print("Time taken for the Network to train : ", elapsedTime)
    
    # Append results
    y_train_pred = classifier.predict(X_train)>0.5
    y_pred_model = classifier.predict(X_test)
    y_test_pred = (y_pred_model>0.5)

    fpr_model, tpr_model, thresholds_model = roc_curve(y_test, y_pred_model.ravel())
    auc_model = auc(fpr_model, tpr_model)
    print(auc_model, '\n\n')
    
    history.append(hist)
    auc_score.append(auc_model)
    TrainSet_ConfusionMatrix.append(confusion_matrix(y_train, y_train_pred))
    TestSet_ConfusionMatrix.append(confusion_matrix(y_test, y_test_pred))
    fpr_and_tpr.append((fpr_model, tpr_model))
    
print("Done!")
# Out:
# K-Fold  0 :
# Train: [ 3966  3967  3968 ... 19951 19952 19953] Validation: [   0    1    2 ... 4168 4172 4173]
# 16782
# 16782
# [8391 8391]
# Train on 16782 samples, validate on 3991 samples
# Epoch 1/75
# 16782/16782 [==============================] - 2s 105us/step - loss: 0.6932 - acc: 0.5012 - precision: 0.2304 - recall: 0.4591 - auroc: 0.4997 - val_loss: 0.6923 - val_acc: 0.7477 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auroc: 0.5000
# Epoch 2/75
# 16782/16782 [==============================] - 2s 90us/step - loss: 0.6453 - acc: 0.6030 - precision: 0.5200 - recall: 0.4862 - auroc: 0.6573 - val_loss: 0.6808 - val_acc: 0.5678 - val_precision: 0.3348 - val_recall: 0.7171 - val_auroc: 0.6828
# Epoch 3/75
# 16782/16782 [==============================] - 1s 86us/step - loss: 0.6246 - acc: 0.6329 - precision: 0.6233 - recall: 0.6728 - auroc: 0.6941 - val_loss: 0.6313 - val_acc: 0.6166 - val_precision: 0.3571 - val_recall: 0.6520 - val_auroc: 0.6857
# Epoch 4/75
# 16782/16782 [==============================] - 1s 86us/step - loss: 0.6209 - acc: 0.6346 - precision: 0.6245 - recall: 0.6799 - auroc: 0.6987 - val_loss: 0.6067 - val_acc: 0.6279 - val_precision: 0.3608 - val_recall: 0.6250 - val_auroc: 0.6881
# Epoch 5/75
# 16782/16782 [==============================] - 2s 96us/step - loss: 0.6179 - acc: 0.6348 - precision: 0.6263 - recall: 0.6710 - auroc: 0.7011 - val_loss: 0.6360 - val_acc: 0.5958 - val_precision: 0.3446 - val_recall: 0.6728 - val_auroc: 0.6876
# Epoch 6/75
# 16782/16782 [==============================] - 1s 89us/step - loss: 0.6155 - acc: 0.6394 - precision: 0.6264 - recall: 0.6947 - auroc: 0.7058 - val_loss: 0.6181 - val_acc: 0.6126 - val_precision: 0.3529 - val_recall: 0.6531 - val_auroc: 0.6875
# Epoch 7/75
# 16782/16782 [==============================] - 1s 86us/step - loss: 0.6131 - acc: 0.6393 - precision: 0.6292 - recall: 0.6825 - auroc: 0.7075 - val_loss: 0.6247 - val_acc: 0.6026 - val_precision: 0.3475 - val_recall: 0.6588 - val_auroc: 0.6913
# Epoch 8/75
# 16782/16782 [==============================] - 1s 89us/step - loss: 0.6123 - acc: 0.6396 - precision: 0.6276 - recall: 0.6833 - auroc: 0.7069 - val_loss: 0.6291 - val_acc: 0.5998 - val_precision: 0.3489 - val_recall: 0.6772 - val_auroc: 0.6906
# Epoch 9/75
# 16782/16782 [==============================] - 1s 87us/step - loss: 0.6121 - acc: 0.6402 - precision: 0.6278 - recall: 0.6932 - auroc: 0.7079 - val_loss: 0.6254 - val_acc: 0.5998 - val_precision: 0.3485 - val_recall: 0.6742 - val_auroc: 0.6914
# Epoch 10/75
# 16782/16782 [==============================] - 1s 87us/step - loss: 0.6122 - acc: 0.6416 - precision: 0.6266 - recall: 0.6970 - auroc: 0.7079 - val_loss: 0.6219 - val_acc: 0.5978 - val_precision: 0.3459 - val_recall: 0.6669 - val_auroc: 0.6881
# Epoch 11/75
# 16782/16782 [==============================] - 1s 88us/step - loss: 0.6121 - acc: 0.6410 - precision: 0.6284 - recall: 0.6925 - auroc: 0.7072 - val_loss: 0.6227 - val_acc: 0.6024 - val_precision: 0.3505 - val_recall: 0.6733 - val_auroc: 0.6902
# Epoch 12/75
# 16782/16782 [==============================] - 2s 90us/step - loss: 0.6125 - acc: 0.6404 - precision: 0.6271 - recall: 0.6922 - auroc: 0.7048 - val_loss: 0.6268 - val_acc: 0.5971 - val_precision: 0.3488 - val_recall: 0.6889 - val_auroc: 0.6927
# Epoch 13/75
# 16782/16782 [==============================] - 2s 90us/step - loss: 0.6108 - acc: 0.6421 - precision: 0.6276 - recall: 0.6923 - auroc: 0.7088 - val_loss: 0.6291 - val_acc: 0.5933 - val_precision: 0.3488 - val_recall: 0.7040 - val_auroc: 0.6923
# Epoch 14/75
# 16782/16782 [==============================] - 2s 91us/step - loss: 0.6096 - acc: 0.6422 - precision: 0.6267 - recall: 0.7041 - auroc: 0.7111 - val_loss: 0.6167 - val_acc: 0.6089 - val_precision: 0.3531 - val_recall: 0.6664 - val_auroc: 0.6924
# Epoch 15/75
# 16782/16782 [==============================] - 2s 92us/step - loss: 0.6081 - acc: 0.6413 - precision: 0.6270 - recall: 0.7021 - auroc: 0.7093 - val_loss: 0.6204 - val_acc: 0.6059 - val_precision: 0.3541 - val_recall: 0.6818 - val_auroc: 0.6936
# Epoch 16/75
# 16782/16782 [==============================] - 1s 87us/step - loss: 0.6066 - acc: 0.6439 - precision: 0.6289 - recall: 0.7009 - auroc: 0.7128 - val_loss: 0.6187 - val_acc: 0.6071 - val_precision: 0.3537 - val_recall: 0.6737 - val_auroc: 0.6928
# Epoch 17/75
# 16782/16782 [==============================] - 1s 88us/step - loss: 0.6075 - acc: 0.6431 - precision: 0.6288 - recall: 0.7042 - auroc: 0.7128 - val_loss: 0.6196 - val_acc: 0.6001 - val_precision: 0.3510 - val_recall: 0.6839 - val_auroc: 0.6921
# Epoch 18/75
# 16782/16782 [==============================] - 1s 88us/step - loss: 0.6082 - acc: 0.6463 - precision: 0.6298 - recall: 0.7093 - auroc: 0.7132 - val_loss: 0.6254 - val_acc: 0.5968 - val_precision: 0.3499 - val_recall: 0.6954 - val_auroc: 0.6929
# Epoch 19/75
# 16782/16782 [==============================] - 1s 89us/step - loss: 0.6079 - acc: 0.6425 - precision: 0.6262 - recall: 0.7150 - auroc: 0.7137 - val_loss: 0.6095 - val_acc: 0.6156 - val_precision: 0.3581 - val_recall: 0.6615 - val_auroc: 0.6941
# Epoch 20/75
# 16782/16782 [==============================] - 2s 89us/step - loss: 0.6079 - acc: 0.6418 - precision: 0.6284 - recall: 0.6947 - auroc: 0.7120 - val_loss: 0.6192 - val_acc: 0.6044 - val_precision: 0.3531 - val_recall: 0.6818 - val_auroc: 0.6946
# Epoch 21/75
# 16782/16782 [==============================] - 2s 99us/step - loss: 0.6076 - acc: 0.6432 - precision: 0.6255 - recall: 0.7121 - auroc: 0.7141 - val_loss: 0.6180 - val_acc: 0.6059 - val_precision: 0.3542 - val_recall: 0.6849 - val_auroc: 0.6939
# Epoch 22/75
# 16782/16782 [==============================] - 2s 95us/step - loss: 0.6059 - acc: 0.6466 - precision: 0.6313 - recall: 0.7050 - auroc: 0.7148 - val_loss: 0.6251 - val_acc: 0.6014 - val_precision: 0.3534 - val_recall: 0.6984 - val_auroc: 0.6946
# Epoch 23/75
# 16782/16782 [==============================] - 2s 98us/step - loss: 0.6047 - acc: 0.6478 - precision: 0.6316 - recall: 0.7135 - auroc: 0.7166 - val_loss: 0.6204 - val_acc: 0.6036 - val_precision: 0.3527 - val_recall: 0.6874 - val_auroc: 0.6943
# Epoch 24/75
# 16782/16782 [==============================] - 2s 97us/step - loss: 0.6055 - acc: 0.6441 - precision: 0.6277 - recall: 0.7088 - auroc: 0.7152 - val_loss: 0.6210 - val_acc: 0.6021 - val_precision: 0.3530 - val_recall: 0.6954 - val_auroc: 0.6947
# Epoch 25/75
# 16782/16782 [==============================] - 1s 88us/step - loss: 0.6055 - acc: 0.6474 - precision: 0.6302 - recall: 0.7117 - auroc: 0.7144 - val_loss: 0.6197 - val_acc: 0.6061 - val_precision: 0.3553 - val_recall: 0.6870 - val_auroc: 0.6939
# Epoch 26/75
# 16782/16782 [==============================] - 2s 92us/step - loss: 0.6061 - acc: 0.6440 - precision: 0.6273 - recall: 0.7082 - auroc: 0.7126 - val_loss: 0.6194 - val_acc: 0.6059 - val_precision: 0.3559 - val_recall: 0.6912 - val_auroc: 0.6950
# Epoch 27/75
# 16782/16782 [==============================] - 2s 93us/step - loss: 0.6051 - acc: 0.6460 - precision: 0.6291 - recall: 0.7091 - auroc: 0.7140 - val_loss: 0.6207 - val_acc: 0.5983 - val_precision: 0.3517 - val_recall: 0.7047 - val_auroc: 0.6946
# Epoch 28/75
# 16782/16782 [==============================] - 2s 90us/step - loss: 0.6053 - acc: 0.6452 - precision: 0.6304 - recall: 0.7038 - auroc: 0.7172 - val_loss: 0.6208 - val_acc: 0.6016 - val_precision: 0.3534 - val_recall: 0.6957 - val_auroc: 0.6959
# Epoch 29/75
# 16782/16782 [==============================] - 2s 93us/step - loss: 0.6048 - acc: 0.6475 - precision: 0.6306 - recall: 0.7141 - auroc: 0.7159 - val_loss: 0.6251 - val_acc: 0.6006 - val_precision: 0.3534 - val_recall: 0.7050 - val_auroc: 0.6955
# Epoch 30/75
# 16782/16782 [==============================] - 2s 92us/step - loss: 0.6046 - acc: 0.6459 - precision: 0.6289 - recall: 0.7141 - auroc: 0.7170 - val_loss: 0.6187 - val_acc: 0.6046 - val_precision: 0.3540 - val_recall: 0.6886 - val_auroc: 0.6965
# Epoch 31/75
# 16782/16782 [==============================] - 2s 91us/step - loss: 0.6038 - acc: 0.6481 - precision: 0.6350 - recall: 0.7037 - auroc: 0.7184 - val_loss: 0.6243 - val_acc: 0.6019 - val_precision: 0.3536 - val_recall: 0.6997 - val_auroc: 0.6955
# Epoch 32/75
# 16782/16782 [==============================] - 2s 91us/step - loss: 0.6026 - acc: 0.6484 - precision: 0.6315 - recall: 0.7101 - auroc: 0.7174 - val_loss: 0.6204 - val_acc: 0.6031 - val_precision: 0.3538 - val_recall: 0.6910 - val_auroc: 0.6962
# Epoch 33/75
# 16782/16782 [==============================] - 2s 91us/step - loss: 0.6041 - acc: 0.6462 - precision: 0.6305 - recall: 0.7062 - auroc: 0.7179 - val_loss: 0.6216 - val_acc: 0.6021 - val_precision: 0.3537 - val_recall: 0.6952 - val_auroc: 0.6954
# Epoch 34/75
# 16782/16782 [==============================] - 2s 91us/step - loss: 0.6040 - acc: 0.6466 - precision: 0.6302 - recall: 0.7104 - auroc: 0.7154 - val_loss: 0.6273 - val_acc: 0.5951 - val_precision: 0.3502 - val_recall: 0.7126 - val_auroc: 0.6950
# Epoch 35/75
# 16782/16782 [==============================] - 2s 93us/step - loss: 0.6040 - acc: 0.6473 - precision: 0.6293 - recall: 0.7174 - auroc: 0.7156 - val_loss: 0.6172 - val_acc: 0.6054 - val_precision: 0.3550 - val_recall: 0.6857 - val_auroc: 0.6945
# Epoch 36/75
# 16782/16782 [==============================] - 2s 93us/step - loss: 0.6028 - acc: 0.6445 - precision: 0.6277 - recall: 0.7162 - auroc: 0.7176 - val_loss: 0.6219 - val_acc: 0.6006 - val_precision: 0.3536 - val_recall: 0.7050 - val_auroc: 0.6955
# Epoch 37/75
# 16782/16782 [==============================] - 2s 94us/step - loss: 0.6023 - acc: 0.6460 - precision: 0.6282 - recall: 0.7135 - auroc: 0.7171 - val_loss: 0.6198 - val_acc: 0.6014 - val_precision: 0.3522 - val_recall: 0.6930 - val_auroc: 0.6955
# Epoch 38/75
# 16782/16782 [==============================] - 2s 94us/step - loss: 0.6024 - acc: 0.6455 - precision: 0.6292 - recall: 0.7135 - auroc: 0.7174 - val_loss: 0.6179 - val_acc: 0.6034 - val_precision: 0.3534 - val_recall: 0.6896 - val_auroc: 0.6953
# Epoch 39/75
# 16782/16782 [==============================] - 2s 94us/step - loss: 0.6016 - acc: 0.6490 - precision: 0.6323 - recall: 0.7136 - auroc: 0.7191 - val_loss: 0.6157 - val_acc: 0.6069 - val_precision: 0.3550 - val_recall: 0.6838 - val_auroc: 0.6955
# Epoch 40/75
# 16782/16782 [==============================] - 2s 94us/step - loss: 0.6028 - acc: 0.6484 - precision: 0.6302 - recall: 0.7131 - auroc: 0.7186 - val_loss: 0.6172 - val_acc: 0.6014 - val_precision: 0.3515 - val_recall: 0.6901 - val_auroc: 0.6950
# Epoch 41/75
# 16782/16782 [==============================] - 2s 94us/step - loss: 0.6025 - acc: 0.6466 - precision: 0.6283 - recall: 0.7149 - auroc: 0.7177 - val_loss: 0.6196 - val_acc: 0.5993 - val_precision: 0.3519 - val_recall: 0.7007 - val_auroc: 0.6942
# Epoch 42/75
# 16782/16782 [==============================] - 2s 95us/step - loss: 0.6037 - acc: 0.6466 - precision: 0.6285 - recall: 0.7128 - auroc: 0.7184 - val_loss: 0.6233 - val_acc: 0.5978 - val_precision: 0.3511 - val_recall: 0.7027 - val_auroc: 0.6954
# Epoch 43/75
# 16782/16782 [==============================] - 2s 93us/step - loss: 0.6024 - acc: 0.6463 - precision: 0.6290 - recall: 0.7125 - auroc: 0.7176 - val_loss: 0.6159 - val_acc: 0.6071 - val_precision: 0.3560 - val_recall: 0.6865 - val_auroc: 0.6951
# Epoch 44/75
# 16782/16782 [==============================] - 2s 95us/step - loss: 0.6016 - acc: 0.6491 - precision: 0.6301 - recall: 0.7172 - auroc: 0.7180 - val_loss: 0.6182 - val_acc: 0.6039 - val_precision: 0.3539 - val_recall: 0.6912 - val_auroc: 0.6951
# Epoch 45/75
# 16782/16782 [==============================] - 2s 94us/step - loss: 0.6009 - acc: 0.6474 - precision: 0.6298 - recall: 0.7108 - auroc: 0.7177 - val_loss: 0.6187 - val_acc: 0.6014 - val_precision: 0.3519 - val_recall: 0.6927 - val_auroc: 0.6954
# Epoch 46/75
# 16782/16782 [==============================] - 2s 93us/step - loss: 0.6010 - acc: 0.6472 - precision: 0.6297 - recall: 0.7169 - auroc: 0.7187 - val_loss: 0.6174 - val_acc: 0.6029 - val_precision: 0.3534 - val_recall: 0.6909 - val_auroc: 0.6951
# Epoch 47/75
# 16782/16782 [==============================] - 2s 97us/step - loss: 0.6009 - acc: 0.6477 - precision: 0.6303 - recall: 0.7185 - auroc: 0.7203 - val_loss: 0.6179 - val_acc: 0.6031 - val_precision: 0.3538 - val_recall: 0.6902 - val_auroc: 0.6953
# Epoch 48/75
# 16782/16782 [==============================] - 2s 95us/step - loss: 0.6018 - acc: 0.6491 - precision: 0.6319 - recall: 0.7099 - auroc: 0.7201 - val_loss: 0.6215 - val_acc: 0.6021 - val_precision: 0.3527 - val_recall: 0.6955 - val_auroc: 0.6943
# Epoch 49/75
# 16782/16782 [==============================] - 2s 95us/step - loss: 0.6013 - acc: 0.6466 - precision: 0.6292 - recall: 0.7135 - auroc: 0.7193 - val_loss: 0.6232 - val_acc: 0.5993 - val_precision: 0.3515 - val_recall: 0.6971 - val_auroc: 0.6957
# Epoch 50/75
# 16782/16782 [==============================] - 2s 97us/step - loss: 0.6016 - acc: 0.6465 - precision: 0.6302 - recall: 0.7162 - auroc: 0.7197 - val_loss: 0.6201 - val_acc: 0.6046 - val_precision: 0.3547 - val_recall: 0.6922 - val_auroc: 0.6965
# Epoch 51/75
# 16782/16782 [==============================] - 2s 97us/step - loss: 0.6011 - acc: 0.6501 - precision: 0.6340 - recall: 0.7079 - auroc: 0.7200 - val_loss: 0.6228 - val_acc: 0.5956 - val_precision: 0.3511 - val_recall: 0.7096 - val_auroc: 0.6962
# Epoch 52/75
# 16782/16782 [==============================] - 2s 91us/step - loss: 0.6008 - acc: 0.6500 - precision: 0.6315 - recall: 0.7176 - auroc: 0.7203 - val_loss: 0.6192 - val_acc: 0.6016 - val_precision: 0.3522 - val_recall: 0.6927 - val_auroc: 0.6967
# Epoch 53/75
# 16782/16782 [==============================] - 2s 92us/step - loss: 0.5990 - acc: 0.6488 - precision: 0.6308 - recall: 0.7140 - auroc: 0.7223 - val_loss: 0.6176 - val_acc: 0.6036 - val_precision: 0.3536 - val_recall: 0.6921 - val_auroc: 0.6965
# Epoch 54/75
# 16782/16782 [==============================] - 2s 93us/step - loss: 0.6005 - acc: 0.6522 - precision: 0.6359 - recall: 0.7169 - auroc: 0.7214 - val_loss: 0.6191 - val_acc: 0.6024 - val_precision: 0.3531 - val_recall: 0.6938 - val_auroc: 0.6962
# Epoch 55/75
# 16782/16782 [==============================] - 2s 93us/step - loss: 0.5995 - acc: 0.6481 - precision: 0.6312 - recall: 0.7103 - auroc: 0.7206 - val_loss: 0.6180 - val_acc: 0.6041 - val_precision: 0.3545 - val_recall: 0.6930 - val_auroc: 0.6970
# Epoch 56/75
# 16782/16782 [==============================] - 2s 93us/step - loss: 0.5996 - acc: 0.6492 - precision: 0.6310 - recall: 0.7125 - auroc: 0.7202 - val_loss: 0.6179 - val_acc: 0.6046 - val_precision: 0.3547 - val_recall: 0.6930 - val_auroc: 0.6968
# Epoch 57/75
# 16782/16782 [==============================] - 2s 93us/step - loss: 0.6005 - acc: 0.6500 - precision: 0.6331 - recall: 0.7142 - auroc: 0.7229 - val_loss: 0.6212 - val_acc: 0.6031 - val_precision: 0.3543 - val_recall: 0.6985 - val_auroc: 0.6972
# Epoch 58/75
# 16782/16782 [==============================] - 2s 92us/step - loss: 0.5990 - acc: 0.6527 - precision: 0.6357 - recall: 0.7173 - auroc: 0.7209 - val_loss: 0.6173 - val_acc: 0.6054 - val_precision: 0.3546 - val_recall: 0.6886 - val_auroc: 0.6965
# Epoch 59/75
# 16782/16782 [==============================] - 2s 91us/step - loss: 0.5984 - acc: 0.6510 - precision: 0.6345 - recall: 0.7109 - auroc: 0.7221 - val_loss: 0.6163 - val_acc: 0.6069 - val_precision: 0.3555 - val_recall: 0.6863 - val_auroc: 0.6965
# Epoch 60/75
# 16782/16782 [==============================] - 2s 92us/step - loss: 0.5993 - acc: 0.6499 - precision: 0.6334 - recall: 0.7137 - auroc: 0.7222 - val_loss: 0.6212 - val_acc: 0.6036 - val_precision: 0.3547 - val_recall: 0.6989 - val_auroc: 0.6978
# Epoch 61/75
# 16782/16782 [==============================] - 2s 93us/step - loss: 0.6004 - acc: 0.6486 - precision: 0.6307 - recall: 0.7177 - auroc: 0.7194 - val_loss: 0.6185 - val_acc: 0.6069 - val_precision: 0.3569 - val_recall: 0.6953 - val_auroc: 0.6975
# Epoch 62/75
# 16782/16782 [==============================] - 2s 95us/step - loss: 0.5990 - acc: 0.6515 - precision: 0.6348 - recall: 0.7157 - auroc: 0.7245 - val_loss: 0.6181 - val_acc: 0.6061 - val_precision: 0.3560 - val_recall: 0.6917 - val_auroc: 0.6974
# Epoch 63/75
# 16782/16782 [==============================] - 2s 91us/step - loss: 0.6001 - acc: 0.6490 - precision: 0.6320 - recall: 0.7118 - auroc: 0.7210 - val_loss: 0.6168 - val_acc: 0.6089 - val_precision: 0.3561 - val_recall: 0.6820 - val_auroc: 0.6969
# Epoch 64/75
# 16782/16782 [==============================] - 2s 90us/step - loss: 0.5995 - acc: 0.6475 - precision: 0.6307 - recall: 0.7125 - auroc: 0.7211 - val_loss: 0.6095 - val_acc: 0.6174 - val_precision: 0.3606 - val_recall: 0.6687 - val_auroc: 0.6974
# Epoch 65/75
# 16782/16782 [==============================] - 2s 90us/step - loss: 0.5991 - acc: 0.6500 - precision: 0.6342 - recall: 0.7132 - auroc: 0.7213 - val_loss: 0.6238 - val_acc: 0.6011 - val_precision: 0.3533 - val_recall: 0.7005 - val_auroc: 0.6971
# Epoch 66/75
# 16782/16782 [==============================] - 2s 90us/step - loss: 0.6000 - acc: 0.6504 - precision: 0.6337 - recall: 0.7181 - auroc: 0.7222 - val_loss: 0.6168 - val_acc: 0.6096 - val_precision: 0.3575 - val_recall: 0.6875 - val_auroc: 0.6966
# Epoch 67/75
# 16782/16782 [==============================] - 2s 90us/step - loss: 0.5985 - acc: 0.6491 - precision: 0.6304 - recall: 0.7164 - auroc: 0.7210 - val_loss: 0.6132 - val_acc: 0.6144 - val_precision: 0.3589 - val_recall: 0.6738 - val_auroc: 0.6972
# Epoch 68/75
# 16782/16782 [==============================] - 2s 93us/step - loss: 0.5978 - acc: 0.6506 - precision: 0.6349 - recall: 0.7070 - auroc: 0.7227 - val_loss: 0.6187 - val_acc: 0.6081 - val_precision: 0.3570 - val_recall: 0.6910 - val_auroc: 0.6971
# Epoch 69/75
# 16782/16782 [==============================] - 2s 91us/step - loss: 0.5998 - acc: 0.6517 - precision: 0.6351 - recall: 0.7144 - auroc: 0.7197 - val_loss: 0.6186 - val_acc: 0.6084 - val_precision: 0.3575 - val_recall: 0.6914 - val_auroc: 0.6972
# Epoch 70/75
# 16782/16782 [==============================] - 2s 92us/step - loss: 0.5988 - acc: 0.6505 - precision: 0.6339 - recall: 0.7122 - auroc: 0.7223 - val_loss: 0.6178 - val_acc: 0.6091 - val_precision: 0.3576 - val_recall: 0.6883 - val_auroc: 0.6970
# Epoch 71/75
# 16782/16782 [==============================] - 2s 92us/step - loss: 0.6003 - acc: 0.6509 - precision: 0.6346 - recall: 0.7125 - auroc: 0.7198 - val_loss: 0.6177 - val_acc: 0.6091 - val_precision: 0.3587 - val_recall: 0.6932 - val_auroc: 0.6974
# Epoch 72/75
# 16782/16782 [==============================] - 2s 91us/step - loss: 0.5980 - acc: 0.6506 - precision: 0.6328 - recall: 0.7137 - auroc: 0.7228 - val_loss: 0.6184 - val_acc: 0.6039 - val_precision: 0.3551 - val_recall: 0.6951 - val_auroc: 0.6979
# Epoch 73/75
# 16782/16782 [==============================] - 2s 90us/step - loss: 0.5995 - acc: 0.6514 - precision: 0.6369 - recall: 0.7140 - auroc: 0.7229 - val_loss: 0.6141 - val_acc: 0.6119 - val_precision: 0.3578 - val_recall: 0.6782 - val_auroc: 0.6963
# Epoch 74/75
# 16782/16782 [==============================] - 2s 90us/step - loss: 0.5989 - acc: 0.6493 - precision: 0.6348 - recall: 0.7136 - auroc: 0.7226 - val_loss: 0.6216 - val_acc: 0.6019 - val_precision: 0.3535 - val_recall: 0.6952 - val_auroc: 0.6982
# Epoch 75/75
# 16782/16782 [==============================] - 2s 90us/step - loss: 0.5988 - acc: 0.6501 - precision: 0.6334 - recall: 0.7144 - auroc: 0.7222 - val_loss: 0.6190 - val_acc: 0.6061 - val_precision: 0.3559 - val_recall: 0.6926 - val_auroc: 0.6981
# Time taken for the Network to train :  116.8904879999991
# 0.7085669453680052
#
#
# K-Fold  0 :
# Train: [    0     1     2 ... 19951 19952 19953] Validation: [3966 3967 3968 ... 8693 8695 8696]
# 16784
# 16784
# [8392 8392]
# Train on 16784 samples, validate on 3991 samples
# Epoch 1/75
# 16784/16784 [==============================] - 2s 91us/step - loss: 0.6060 - acc: 0.6460 - precision: 0.6292 - recall: 0.7096 - auroc: 0.7152 - val_loss: 0.6195 - val_acc: 0.6084 - val_precision: 0.3582 - val_recall: 0.6960 - val_auroc: 0.6989
# Epoch 2/75
# 16784/16784 [==============================] - 2s 91us/step - loss: 0.6042 - acc: 0.6500 - precision: 0.6339 - recall: 0.7080 - auroc: 0.7174 - val_loss: 0.6190 - val_acc: 0.6069 - val_precision: 0.3567 - val_recall: 0.6922 - val_auroc: 0.6988
# Epoch 3/75
# 16784/16784 [==============================] - 2s 92us/step - loss: 0.6047 - acc: 0.6470 - precision: 0.6339 - recall: 0.7110 - auroc: 0.7201 - val_loss: 0.6182 - val_acc: 0.6061 - val_precision: 0.3561 - val_recall: 0.6904 - val_auroc: 0.6976
# Epoch 4/75
# 16784/16784 [==============================] - 2s 95us/step - loss: 0.6031 - acc: 0.6491 - precision: 0.6320 - recall: 0.7100 - auroc: 0.7192 - val_loss: 0.6185 - val_acc: 0.6056 - val_precision: 0.3554 - val_recall: 0.6885 - val_auroc: 0.6983
# Epoch 5/75
# 16784/16784 [==============================] - 2s 97us/step - loss: 0.6040 - acc: 0.6487 - precision: 0.6318 - recall: 0.7146 - auroc: 0.7174 - val_loss: 0.6143 - val_acc: 0.6106 - val_precision: 0.3582 - val_recall: 0.6834 - val_auroc: 0.6965
# Epoch 6/75
# 16784/16784 [==============================] - 2s 95us/step - loss: 0.6036 - acc: 0.6496 - precision: 0.6328 - recall: 0.7060 - auroc: 0.7186 - val_loss: 0.6247 - val_acc: 0.5968 - val_precision: 0.3519 - val_recall: 0.7090 - val_auroc: 0.6975
# Epoch 7/75
# 16784/16784 [==============================] - 2s 98us/step - loss: 0.6030 - acc: 0.6471 - precision: 0.6301 - recall: 0.7083 - auroc: 0.7190 - val_loss: 0.6193 - val_acc: 0.6029 - val_precision: 0.3550 - val_recall: 0.7039 - val_auroc: 0.6965
# Epoch 8/75
# 16784/16784 [==============================] - 2s 102us/step - loss: 0.6024 - acc: 0.6505 - precision: 0.6325 - recall: 0.7178 - auroc: 0.7208 - val_loss: 0.6195 - val_acc: 0.6019 - val_precision: 0.3547 - val_recall: 0.7037 - val_auroc: 0.6965
# Epoch 9/75
# 16784/16784 [==============================] - 2s 100us/step - loss: 0.6025 - acc: 0.6491 - precision: 0.6320 - recall: 0.7128 - auroc: 0.7187 - val_loss: 0.6184 - val_acc: 0.6039 - val_precision: 0.3559 - val_recall: 0.7021 - val_auroc: 0.6964
# Epoch 10/75
# 16784/16784 [==============================] - 2s 99us/step - loss: 0.6025 - acc: 0.6483 - precision: 0.6315 - recall: 0.7129 - auroc: 0.7172 - val_loss: 0.6173 - val_acc: 0.6046 - val_precision: 0.3557 - val_recall: 0.6952 - val_auroc: 0.6955
# Epoch 11/75
# 16784/16784 [==============================] - 2s 96us/step - loss: 0.6030 - acc: 0.6469 - precision: 0.6305 - recall: 0.7093 - auroc: 0.7165 - val_loss: 0.6194 - val_acc: 0.6021 - val_precision: 0.3546 - val_recall: 0.6997 - val_auroc: 0.6970
# Epoch 12/75
# 16784/16784 [==============================] - 2s 102us/step - loss: 0.6030 - acc: 0.6503 - precision: 0.6334 - recall: 0.7159 - auroc: 0.7192 - val_loss: 0.6247 - val_acc: 0.5953 - val_precision: 0.3509 - val_recall: 0.7095 - val_auroc: 0.6960
# Epoch 13/75
# 16784/16784 [==============================] - 2s 101us/step - loss: 0.6023 - acc: 0.6478 - precision: 0.6309 - recall: 0.7131 - auroc: 0.7219 - val_loss: 0.6172 - val_acc: 0.6039 - val_precision: 0.3555 - val_recall: 0.6992 - val_auroc: 0.6961
# Epoch 14/75
# 16784/16784 [==============================] - 2s 103us/step - loss: 0.6024 - acc: 0.6495 - precision: 0.6321 - recall: 0.7136 - auroc: 0.7196 - val_loss: 0.6215 - val_acc: 0.6004 - val_precision: 0.3536 - val_recall: 0.7008 - val_auroc: 0.6951
# Epoch 15/75
# 16784/16784 [==============================] - 2s 105us/step - loss: 0.6021 - acc: 0.6511 - precision: 0.6359 - recall: 0.7171 - auroc: 0.7231 - val_loss: 0.6183 - val_acc: 0.6046 - val_precision: 0.3556 - val_recall: 0.6955 - val_auroc: 0.6950
# Epoch 16/75
# 16784/16784 [==============================] - 2s 103us/step - loss: 0.6010 - acc: 0.6504 - precision: 0.6334 - recall: 0.7137 - auroc: 0.7196 - val_loss: 0.6198 - val_acc: 0.6019 - val_precision: 0.3547 - val_recall: 0.7013 - val_auroc: 0.6949
# Epoch 17/75
# 16784/16784 [==============================] - 2s 101us/step - loss: 0.6022 - acc: 0.6502 - precision: 0.6330 - recall: 0.7225 - auroc: 0.7207 - val_loss: 0.6180 - val_acc: 0.6039 - val_precision: 0.3555 - val_recall: 0.6993 - val_auroc: 0.6948
# Epoch 18/75
# 16784/16784 [==============================] - 2s 97us/step - loss: 0.6017 - acc: 0.6512 - precision: 0.6341 - recall: 0.7165 - auroc: 0.7223 - val_loss: 0.6182 - val_acc: 0.6046 - val_precision: 0.3563 - val_recall: 0.7005 - val_auroc: 0.6949
# Epoch 19/75
# 16784/16784 [==============================] - 2s 94us/step - loss: 0.6021 - acc: 0.6466 - precision: 0.6288 - recall: 0.7071 - auroc: 0.7177 - val_loss: 0.6201 - val_acc: 0.6014 - val_precision: 0.3540 - val_recall: 0.7016 - val_auroc: 0.6948
# Epoch 20/75
# 16784/16784 [==============================] - 2s 92us/step - loss: 0.6016 - acc: 0.6477 - precision: 0.6321 - recall: 0.7119 - auroc: 0.7194 - val_loss: 0.6199 - val_acc: 0.6016 - val_precision: 0.3554 - val_recall: 0.7096 - val_auroc: 0.6950
# Epoch 21/75
# 16784/16784 [==============================] - 2s 96us/step - loss: 0.6026 - acc: 0.6499 - precision: 0.6326 - recall: 0.7138 - auroc: 0.7181 - val_loss: 0.6213 - val_acc: 0.5998 - val_precision: 0.3540 - val_recall: 0.7134 - val_auroc: 0.6945
# Epoch 22/75
# 16784/16784 [==============================] - 2s 101us/step - loss: 0.6021 - acc: 0.6491 - precision: 0.6291 - recall: 0.7225 - auroc: 0.7164 - val_loss: 0.6180 - val_acc: 0.6036 - val_precision: 0.3561 - val_recall: 0.7064 - val_auroc: 0.6952
# Epoch 23/75
# 16784/16784 [==============================] - 2s 94us/step - loss: 0.6015 - acc: 0.6508 - precision: 0.6324 - recall: 0.7208 - auroc: 0.7202 - val_loss: 0.6193 - val_acc: 0.6016 - val_precision: 0.3544 - val_recall: 0.7056 - val_auroc: 0.6947
# Epoch 24/75
# 16784/16784 [==============================] - ETA: 0s - loss: 0.6006 - acc: 0.6507 - precision: 0.6339 - recall: 0.7187 - auroc: 0.72 - 2s 95us/step - loss: 0.6010 - acc: 0.6504 - precision: 0.6336 - recall: 0.7187 - auroc: 0.7222 - val_loss: 0.6174 - val_acc: 0.6041 - val_precision: 0.3556 - val_recall: 0.7031 - val_auroc: 0.6944
# Epoch 25/75
# 16784/16784 [==============================] - 2s 95us/step - loss: 0.6001 - acc: 0.6525 - precision: 0.6366 - recall: 0.7192 - auroc: 0.7217 - val_loss: 0.6204 - val_acc: 0.6006 - val_precision: 0.3541 - val_recall: 0.7065 - val_auroc: 0.6948
# Epoch 26/75
# 16784/16784 [==============================] - 2s 101us/step - loss: 0.6009 - acc: 0.6520 - precision: 0.6320 - recall: 0.7216 - auroc: 0.7182 - val_loss: 0.6140 - val_acc: 0.6071 - val_precision: 0.3556 - val_recall: 0.6886 - val_auroc: 0.6945
# Epoch 27/75
# 16784/16784 [==============================] - 2s 103us/step - loss: 0.6004 - acc: 0.6510 - precision: 0.6331 - recall: 0.7149 - auroc: 0.7197 - val_loss: 0.6190 - val_acc: 0.6031 - val_precision: 0.3551 - val_recall: 0.7045 - val_auroc: 0.6946
# Epoch 28/75
# 16784/16784 [==============================] - 2s 93us/step - loss: 0.6012 - acc: 0.6515 - precision: 0.6316 - recall: 0.7215 - auroc: 0.7199 - val_loss: 0.6178 - val_acc: 0.6034 - val_precision: 0.3549 - val_recall: 0.7029 - val_auroc: 0.6950
# Epoch 29/75
# 16784/16784 [==============================] - 2s 90us/step - loss: 0.6000 - acc: 0.6516 - precision: 0.6344 - recall: 0.7150 - auroc: 0.7203 - val_loss: 0.6198 - val_acc: 0.6021 - val_precision: 0.3543 - val_recall: 0.7051 - val_auroc: 0.6956
# Epoch 30/75
# 16784/16784 [==============================] - 1s 88us/step - loss: 0.5998 - acc: 0.6501 - precision: 0.6322 - recall: 0.7160 - auroc: 0.7204 - val_loss: 0.6179 - val_acc: 0.6031 - val_precision: 0.3550 - val_recall: 0.7042 - val_auroc: 0.6957
# Epoch 31/75
# 16784/16784 [==============================] - 1s 88us/step - loss: 0.6001 - acc: 0.6510 - precision: 0.6313 - recall: 0.7183 - auroc: 0.7204 - val_loss: 0.6173 - val_acc: 0.6049 - val_precision: 0.3562 - val_recall: 0.7026 - val_auroc: 0.6958
# Epoch 32/75
# 16784/16784 [==============================] - 1s 89us/step - loss: 0.5997 - acc: 0.6504 - precision: 0.6330 - recall: 0.7168 - auroc: 0.7216 - val_loss: 0.6182 - val_acc: 0.6034 - val_precision: 0.3548 - val_recall: 0.7006 - val_auroc: 0.6959
# Epoch 33/75
# 16784/16784 [==============================] - 2s 91us/step - loss: 0.5999 - acc: 0.6510 - precision: 0.6322 - recall: 0.7166 - auroc: 0.7201 - val_loss: 0.6185 - val_acc: 0.6044 - val_precision: 0.3558 - val_recall: 0.7026 - val_auroc: 0.6959
# Epoch 34/75
# 16784/16784 [==============================] - 1s 88us/step - loss: 0.5991 - acc: 0.6501 - precision: 0.6326 - recall: 0.7155 - auroc: 0.7213 - val_loss: 0.6199 - val_acc: 0.6009 - val_precision: 0.3537 - val_recall: 0.7062 - val_auroc: 0.6957
# Epoch 35/75
# 16784/16784 [==============================] - 1s 89us/step - loss: 0.6014 - acc: 0.6510 - precision: 0.6323 - recall: 0.7176 - auroc: 0.7202 - val_loss: 0.6209 - val_acc: 0.6026 - val_precision: 0.3556 - val_recall: 0.7097 - val_auroc: 0.6953
# Epoch 36/75
# 16784/16784 [==============================] - 2s 90us/step - loss: 0.5995 - acc: 0.6530 - precision: 0.6352 - recall: 0.7236 - auroc: 0.7225 - val_loss: 0.6151 - val_acc: 0.6054 - val_precision: 0.3541 - val_recall: 0.6895 - val_auroc: 0.6953
# Epoch 37/75
# 16784/16784 [==============================] - 1s 88us/step - loss: 0.6014 - acc: 0.6500 - precision: 0.6313 - recall: 0.7190 - auroc: 0.7167 - val_loss: 0.6188 - val_acc: 0.6046 - val_precision: 0.3552 - val_recall: 0.6982 - val_auroc: 0.6956
# Epoch 38/75
# 16784/16784 [==============================] - 1s 89us/step - loss: 0.6011 - acc: 0.6505 - precision: 0.6320 - recall: 0.7139 - auroc: 0.7202 - val_loss: 0.6166 - val_acc: 0.6051 - val_precision: 0.3542 - val_recall: 0.6879 - val_auroc: 0.6956
# Epoch 39/75
# 16784/16784 [==============================] - 1s 89us/step - loss: 0.5995 - acc: 0.6515 - precision: 0.6362 - recall: 0.7101 - auroc: 0.7228 - val_loss: 0.6179 - val_acc: 0.6044 - val_precision: 0.3541 - val_recall: 0.6930 - val_auroc: 0.6961
# Epoch 40/75
# 16784/16784 [==============================] - 2s 111us/step - loss: 0.5992 - acc: 0.6503 - precision: 0.6336 - recall: 0.7129 - auroc: 0.7221 - val_loss: 0.6172 - val_acc: 0.6054 - val_precision: 0.3552 - val_recall: 0.6933 - val_auroc: 0.6959
# Epoch 41/75
# 16784/16784 [==============================] - 2s 105us/step - loss: 0.5995 - acc: 0.6523 - precision: 0.6374 - recall: 0.7149 - auroc: 0.7244 - val_loss: 0.6175 - val_acc: 0.6054 - val_precision: 0.3552 - val_recall: 0.6932 - val_auroc: 0.6955
# Epoch 42/75
# 16784/16784 [==============================] - 2s 111us/step - loss: 0.5998 - acc: 0.6520 - precision: 0.6341 - recall: 0.7142 - auroc: 0.7203 - val_loss: 0.6187 - val_acc: 0.6044 - val_precision: 0.3553 - val_recall: 0.6974 - val_auroc: 0.6959
# Epoch 43/75
# 16784/16784 [==============================] - 2s 93us/step - loss: 0.5995 - acc: 0.6493 - precision: 0.6332 - recall: 0.7141 - auroc: 0.7227 - val_loss: 0.6194 - val_acc: 0.6031 - val_precision: 0.3536 - val_recall: 0.6959 - val_auroc: 0.6955
# Epoch 44/75
# 16784/16784 [==============================] - 2s 91us/step - loss: 0.6005 - acc: 0.6490 - precision: 0.6321 - recall: 0.7134 - auroc: 0.7219 - val_loss: 0.6183 - val_acc: 0.6031 - val_precision: 0.3546 - val_recall: 0.6996 - val_auroc: 0.6961
# Epoch 45/75
# 16784/16784 [==============================] - 2s 93us/step - loss: 0.5994 - acc: 0.6540 - precision: 0.6361 - recall: 0.7206 - auroc: 0.7218 - val_loss: 0.6192 - val_acc: 0.6011 - val_precision: 0.3535 - val_recall: 0.7013 - val_auroc: 0.6960
# Epoch 46/75
# 16784/16784 [==============================] - 2s 94us/step - loss: 0.5995 - acc: 0.6503 - precision: 0.6319 - recall: 0.7184 - auroc: 0.7245 - val_loss: 0.6173 - val_acc: 0.6044 - val_precision: 0.3548 - val_recall: 0.6968 - val_auroc: 0.6953
# Epoch 47/75
# 16784/16784 [==============================] - 2s 100us/step - loss: 0.5991 - acc: 0.6542 - precision: 0.6384 - recall: 0.7184 - auroc: 0.7239 - val_loss: 0.6182 - val_acc: 0.6034 - val_precision: 0.3547 - val_recall: 0.6998 - val_auroc: 0.6952
# Epoch 48/75
# 16784/16784 [==============================] - 2s 98us/step - loss: 0.5996 - acc: 0.6495 - precision: 0.6332 - recall: 0.7169 - auroc: 0.7215 - val_loss: 0.6195 - val_acc: 0.6011 - val_precision: 0.3539 - val_recall: 0.7060 - val_auroc: 0.6957
# Epoch 49/75
# 16784/16784 [==============================] - 2s 92us/step - loss: 0.5991 - acc: 0.6518 - precision: 0.6327 - recall: 0.7191 - auroc: 0.7212 - val_loss: 0.6169 - val_acc: 0.6051 - val_precision: 0.3558 - val_recall: 0.7002 - val_auroc: 0.6963
# Epoch 50/75
# 16784/16784 [==============================] - 2s 103us/step - loss: 0.5996 - acc: 0.6506 - precision: 0.6327 - recall: 0.7182 - auroc: 0.7232 - val_loss: 0.6186 - val_acc: 0.6031 - val_precision: 0.3548 - val_recall: 0.7009 - val_auroc: 0.6964
# Epoch 51/75
# 16784/16784 [==============================] - 2s 104us/step - loss: 0.5992 - acc: 0.6507 - precision: 0.6330 - recall: 0.7182 - auroc: 0.7221 - val_loss: 0.6171 - val_acc: 0.6054 - val_precision: 0.3554 - val_recall: 0.6977 - val_auroc: 0.6957
# Epoch 52/75
# 16784/16784 [==============================] - 1s 87us/step - loss: 0.5982 - acc: 0.6516 - precision: 0.6336 - recall: 0.7153 - auroc: 0.7235 - val_loss: 0.6207 - val_acc: 0.6031 - val_precision: 0.3543 - val_recall: 0.7004 - val_auroc: 0.6968
# Epoch 53/75
# 16784/16784 [==============================] - 2s 95us/step - loss: 0.5988 - acc: 0.6532 - precision: 0.6347 - recall: 0.7189 - auroc: 0.7231 - val_loss: 0.6169 - val_acc: 0.6044 - val_precision: 0.3538 - val_recall: 0.6915 - val_auroc: 0.6965
# Epoch 54/75
# 16784/16784 [==============================] - 1s 89us/step - loss: 0.5991 - acc: 0.6519 - precision: 0.6353 - recall: 0.7174 - auroc: 0.7223 - val_loss: 0.6185 - val_acc: 0.6031 - val_precision: 0.3536 - val_recall: 0.6947 - val_auroc: 0.6963
# Epoch 55/75
# 16784/16784 [==============================] - 1s 88us/step - loss: 0.5968 - acc: 0.6511 - precision: 0.6325 - recall: 0.7170 - auroc: 0.7234 - val_loss: 0.6177 - val_acc: 0.6034 - val_precision: 0.3538 - val_recall: 0.6952 - val_auroc: 0.6966
# Epoch 56/75
# 16784/16784 [==============================] - 2s 93us/step - loss: 0.5981 - acc: 0.6529 - precision: 0.6359 - recall: 0.7150 - auroc: 0.7237 - val_loss: 0.6188 - val_acc: 0.6014 - val_precision: 0.3532 - val_recall: 0.6975 - val_auroc: 0.6966
# Epoch 57/75
# 16784/16784 [==============================] - 2s 93us/step - loss: 0.5992 - acc: 0.6511 - precision: 0.6328 - recall: 0.7228 - auroc: 0.7236 - val_loss: 0.6182 - val_acc: 0.6024 - val_precision: 0.3538 - val_recall: 0.6984 - val_auroc: 0.6965
# Epoch 58/75
# 16784/16784 [==============================] - 2s 94us/step - loss: 0.5992 - acc: 0.6500 - precision: 0.6322 - recall: 0.7130 - auroc: 0.7194 - val_loss: 0.6201 - val_acc: 0.5993 - val_precision: 0.3527 - val_recall: 0.7021 - val_auroc: 0.6974
# Epoch 59/75
# 16784/16784 [==============================] - 2s 96us/step - loss: 0.5969 - acc: 0.6519 - precision: 0.6339 - recall: 0.7170 - auroc: 0.7230 - val_loss: 0.6210 - val_acc: 0.5993 - val_precision: 0.3531 - val_recall: 0.7066 - val_auroc: 0.6970
# Epoch 60/75
# 16784/16784 [==============================] - 2s 103us/step - loss: 0.5977 - acc: 0.6551 - precision: 0.6363 - recall: 0.7211 - auroc: 0.7248 - val_loss: 0.6157 - val_acc: 0.6044 - val_precision: 0.3541 - val_recall: 0.6926 - val_auroc: 0.6969
# Epoch 61/75
# 16784/16784 [==============================] - 2s 91us/step - loss: 0.5983 - acc: 0.6528 - precision: 0.6332 - recall: 0.7173 - auroc: 0.7227 - val_loss: 0.6177 - val_acc: 0.6016 - val_precision: 0.3530 - val_recall: 0.6985 - val_auroc: 0.6979
# Epoch 62/75
# 16784/16784 [==============================] - 1s 87us/step - loss: 0.5973 - acc: 0.6522 - precision: 0.6342 - recall: 0.7194 - auroc: 0.7234 - val_loss: 0.6172 - val_acc: 0.6016 - val_precision: 0.3531 - val_recall: 0.6985 - val_auroc: 0.697788 - acc: 0.6438 - precision: 0.6260 - recall: 0.7084 - auroc: 0.71 - ETA: 0s - loss: 0.5987 - acc: 0.6459 - precision: 0.6279 - recall:
# Epoch 63/75
# 16784/16784 [==============================] - 2s 98us/step - loss: 0.5988 - acc: 0.6512 - precision: 0.6331 - recall: 0.7184 - auroc: 0.7226 - val_loss: 0.6190 - val_acc: 0.5988 - val_precision: 0.3514 - val_recall: 0.6985 - val_auroc: 0.6980
# Epoch 64/75
# 16784/16784 [==============================] - 2s 109us/step - loss: 0.5973 - acc: 0.6501 - precision: 0.6322 - recall: 0.7205 - auroc: 0.7248 - val_loss: 0.6182 - val_acc: 0.6009 - val_precision: 0.3526 - val_recall: 0.6985 - val_auroc: 0.6974
# Epoch 65/75
# 16784/16784 [==============================] - 2s 99us/step - loss: 0.5975 - acc: 0.6562 - precision: 0.6380 - recall: 0.7294 - auroc: 0.7259 - val_loss: 0.6178 - val_acc: 0.6009 - val_precision: 0.3527 - val_recall: 0.6995 - val_auroc: 0.6977
# Epoch 66/75
# 16784/16784 [==============================] - 2s 106us/step - loss: 0.5983 - acc: 0.6531 - precision: 0.6352 - recall: 0.7193 - auroc: 0.7223 - val_loss: 0.6177 - val_acc: 0.6044 - val_precision: 0.3553 - val_recall: 0.6980 - val_auroc: 0.6981
# Epoch 67/75
# 16784/16784 [==============================] - 2s 92us/step - loss: 0.5988 - acc: 0.6520 - precision: 0.6346 - recall: 0.7210 - auroc: 0.7229 - val_loss: 0.6159 - val_acc: 0.6031 - val_precision: 0.3532 - val_recall: 0.6950 - val_auroc: 0.6972
# Epoch 68/75
# 16784/16784 [==============================] - 2s 94us/step - loss: 0.5978 - acc: 0.6521 - precision: 0.6337 - recall: 0.7223 - auroc: 0.7240 - val_loss: 0.6151 - val_acc: 0.6079 - val_precision: 0.3569 - val_recall: 0.6925 - val_auroc: 0.6976
# Epoch 69/75
# 16784/16784 [==============================] - 2s 103us/step - loss: 0.5985 - acc: 0.6522 - precision: 0.6346 - recall: 0.7143 - auroc: 0.7234 - val_loss: 0.6174 - val_acc: 0.6029 - val_precision: 0.3539 - val_recall: 0.6977 - val_auroc: 0.6978
# Epoch 70/75
# 16784/16784 [==============================] - 2s 95us/step - loss: 0.5982 - acc: 0.6520 - precision: 0.6351 - recall: 0.7149 - auroc: 0.7248 - val_loss: 0.6175 - val_acc: 0.6039 - val_precision: 0.3545 - val_recall: 0.6977 - val_auroc: 0.6977
# Epoch 71/75
# 16784/16784 [==============================] - 2s 95us/step - loss: 0.5976 - acc: 0.6532 - precision: 0.6355 - recall: 0.7169 - auroc: 0.7238 - val_loss: 0.6180 - val_acc: 0.6039 - val_precision: 0.3546 - val_recall: 0.6992 - val_auroc: 0.6980
# Epoch 72/75
# 16784/16784 [==============================] - 2s 96us/step - loss: 0.5988 - acc: 0.6522 - precision: 0.6340 - recall: 0.7192 - auroc: 0.7227 - val_loss: 0.6174 - val_acc: 0.6051 - val_precision: 0.3553 - val_recall: 0.6965 - val_auroc: 0.6976
# Epoch 73/75
# 16784/16784 [==============================] - 2s 115us/step - loss: 0.5980 - acc: 0.6534 - precision: 0.6345 - recall: 0.7159 - auroc: 0.7243 - val_loss: 0.6183 - val_acc: 0.6034 - val_precision: 0.3541 - val_recall: 0.6972 - val_auroc: 0.6984
# Epoch 74/75
# 16784/16784 [==============================] - 2s 99us/step - loss: 0.5975 - acc: 0.6534 - precision: 0.6344 - recall: 0.7207 - auroc: 0.7249 - val_loss: 0.6156 - val_acc: 0.6061 - val_precision: 0.3560 - val_recall: 0.6927 - val_auroc: 0.6979
# Epoch 75/75
# 16784/16784 [==============================] - 2s 93us/step - loss: 0.5985 - acc: 0.6506 - precision: 0.6322 - recall: 0.7171 - auroc: 0.7223 - val_loss: 0.6208 - val_acc: 0.6006 - val_precision: 0.3534 - val_recall: 0.7039 - val_auroc: 0.6983
# Time taken for the Network to train :  121.25136310000016
# 0.7076194235818649
#
#
# K-Fold  0 :
# Train: [    0     1     2 ... 19951 19952 19953] Validation: [ 7799  7802  7803 ... 12813 12814 12815]
# 16784
# 16784
# [8392 8392]
# Train on 16784 samples, validate on 3991 samples
# Epoch 1/75
# 16784/16784 [==============================] - 2s 94us/step - loss: 0.5978 - acc: 0.6506 - precision: 0.6320 - recall: 0.7217 - auroc: 0.7244 - val_loss: 0.6166 - val_acc: 0.6041 - val_precision: 0.3552 - val_recall: 0.6961 - val_auroc: 0.6979
# Epoch 2/75
# 16784/16784 [==============================] - 2s 91us/step - loss: 0.5981 - acc: 0.6507 - precision: 0.6322 - recall: 0.7195 - auroc: 0.7230 - val_loss: 0.6176 - val_acc: 0.6026 - val_precision: 0.3546 - val_recall: 0.6992 - val_auroc: 0.6982
# Epoch 3/75
# 16784/16784 [==============================] - 2s 99us/step - loss: 0.5986 - acc: 0.6487 - precision: 0.6290 - recall: 0.7229 - auroc: 0.7240 - val_loss: 0.6176 - val_acc: 0.6036 - val_precision: 0.3556 - val_recall: 0.7004 - val_auroc: 0.6980
# Epoch 4/75
# 16784/16784 [==============================] - 2s 96us/step - loss: 0.5979 - acc: 0.6498 - precision: 0.6320 - recall: 0.7200 - auroc: 0.7239 - val_loss: 0.6190 - val_acc: 0.6016 - val_precision: 0.3544 - val_recall: 0.7023 - val_auroc: 0.6984
# Epoch 5/75
# 16784/16784 [==============================] - 2s 96us/step - loss: 0.5973 - acc: 0.6502 - precision: 0.6300 - recall: 0.7217 - auroc: 0.7262 - val_loss: 0.6164 - val_acc: 0.6054 - val_precision: 0.3569 - val_recall: 0.6984 - val_auroc: 0.6980
# Epoch 6/75
# 16784/16784 [==============================] - 2s 104us/step - loss: 0.5982 - acc: 0.6507 - precision: 0.6333 - recall: 0.7184 - auroc: 0.7242 - val_loss: 0.6151 - val_acc: 0.6074 - val_precision: 0.3573 - val_recall: 0.6932 - val_auroc: 0.6978
# Epoch 7/75
# 16784/16784 [==============================] - 2s 114us/step - loss: 0.5971 - acc: 0.6512 - precision: 0.6351 - recall: 0.7158 - auroc: 0.7251 - val_loss: 0.6174 - val_acc: 0.6046 - val_precision: 0.3559 - val_recall: 0.6973 - val_auroc: 0.6978
# Epoch 8/75
# 16784/16784 [==============================] - 2s 102us/step - loss: 0.5972 - acc: 0.6514 - precision: 0.6329 - recall: 0.7212 - auroc: 0.7243 - val_loss: 0.6160 - val_acc: 0.6086 - val_precision: 0.3585 - val_recall: 0.6936 - val_auroc: 0.6978
# Epoch 9/75
# 16784/16784 [==============================] - 2s 92us/step - loss: 0.5957 - acc: 0.6519 - precision: 0.6344 - recall: 0.7135 - auroc: 0.7255 - val_loss: 0.6176 - val_acc: 0.6069 - val_precision: 0.3575 - val_recall: 0.6954 - val_auroc: 0.6986
# Epoch 10/75
# 16784/16784 [==============================] - 2s 95us/step - loss: 0.5957 - acc: 0.6516 - precision: 0.6342 - recall: 0.7182 - auroc: 0.7261 - val_loss: 0.6167 - val_acc: 0.6074 - val_precision: 0.3577 - val_recall: 0.6938 - val_auroc: 0.6988
# Epoch 11/75
# 16784/16784 [==============================] - 2s 112us/step - loss: 0.5960 - acc: 0.6512 - precision: 0.6332 - recall: 0.7181 - auroc: 0.7250 - val_loss: 0.6176 - val_acc: 0.6059 - val_precision: 0.3569 - val_recall: 0.6960 - val_auroc: 0.6985
# Epoch 12/75
# 16784/16784 [==============================] - 3s 150us/step - loss: 0.5968 - acc: 0.6515 - precision: 0.6345 - recall: 0.7223 - auroc: 0.7254 - val_loss: 0.6177 - val_acc: 0.6079 - val_precision: 0.3584 - val_recall: 0.6952 - val_auroc: 0.6979
# Epoch 13/75
# 16784/16784 [==============================] - 2s 100us/step - loss: 0.5963 - acc: 0.6526 - precision: 0.6354 - recall: 0.7174 - auroc: 0.7250 - val_loss: 0.6187 - val_acc: 0.6054 - val_precision: 0.3567 - val_recall: 0.6972 - val_auroc: 0.6988
# Epoch 14/75
# 16784/16784 [==============================] - 2s 95us/step - loss: 0.5960 - acc: 0.6544 - precision: 0.6361 - recall: 0.7183 - auroc: 0.7271 - val_loss: 0.6186 - val_acc: 0.6079 - val_precision: 0.3580 - val_recall: 0.6911 - val_auroc: 0.6984
# Epoch 15/75
# 16784/16784 [==============================] - 2s 117us/step - loss: 0.5974 - acc: 0.6514 - precision: 0.6327 - recall: 0.7169 - auroc: 0.7263 - val_loss: 0.6161 - val_acc: 0.6086 - val_precision: 0.3578 - val_recall: 0.6850 - val_auroc: 0.6992
# Epoch 16/75
# 16784/16784 [==============================] - 2s 124us/step - loss: 0.5957 - acc: 0.6522 - precision: 0.6353 - recall: 0.7170 - auroc: 0.7252 - val_loss: 0.6161 - val_acc: 0.6081 - val_precision: 0.3568 - val_recall: 0.6834 - val_auroc: 0.6989
# Epoch 17/75
# 16784/16784 [==============================] - 2s 102us/step - loss: 0.5964 - acc: 0.6515 - precision: 0.6341 - recall: 0.7159 - auroc: 0.7253 - val_loss: 0.6163 - val_acc: 0.6084 - val_precision: 0.3572 - val_recall: 0.6844 - val_auroc: 0.6992
# Epoch 18/75
# 16784/16784 [==============================] - 2s 101us/step - loss: 0.5963 - acc: 0.6502 - precision: 0.6358 - recall: 0.7066 - auroc: 0.7264 - val_loss: 0.6163 - val_acc: 0.6084 - val_precision: 0.3572 - val_recall: 0.6844 - val_auroc: 0.6990
# Epoch 19/75
# 16784/16784 [==============================] - 2s 94us/step - loss: 0.5953 - acc: 0.6517 - precision: 0.6349 - recall: 0.7124 - auroc: 0.7271 - val_loss: 0.6170 - val_acc: 0.6089 - val_precision: 0.3584 - val_recall: 0.6912 - val_auroc: 0.6995
# Epoch 20/75
# 16784/16784 [==============================] - 2s 110us/step - loss: 0.5954 - acc: 0.6527 - precision: 0.6368 - recall: 0.7152 - auroc: 0.7279 - val_loss: 0.6173 - val_acc: 0.6084 - val_precision: 0.3584 - val_recall: 0.6897 - val_auroc: 0.6996
# Epoch 21/75
# 16784/16784 [==============================] - 2s 99us/step - loss: 0.5958 - acc: 0.6529 - precision: 0.6364 - recall: 0.7142 - auroc: 0.7271 - val_loss: 0.6174 - val_acc: 0.6101 - val_precision: 0.3593 - val_recall: 0.6906 - val_auroc: 0.6987
# Epoch 22/75
# 16784/16784 [==============================] - 2s 100us/step - loss: 0.5949 - acc: 0.6514 - precision: 0.6343 - recall: 0.7142 - auroc: 0.7277 - val_loss: 0.6160 - val_acc: 0.6109 - val_precision: 0.3593 - val_recall: 0.6875 - val_auroc: 0.6992
# Epoch 23/75
# 16784/16784 [==============================] - 2s 97us/step - loss: 0.5960 - acc: 0.6509 - precision: 0.6324 - recall: 0.7168 - auroc: 0.7237 - val_loss: 0.6148 - val_acc: 0.6106 - val_precision: 0.3580 - val_recall: 0.6840 - val_auroc: 0.6982
# Epoch 24/75
# 16784/16784 [==============================] - 2s 98us/step - loss: 0.5960 - acc: 0.6501 - precision: 0.6337 - recall: 0.7122 - auroc: 0.7258 - val_loss: 0.6158 - val_acc: 0.6096 - val_precision: 0.3577 - val_recall: 0.6862 - val_auroc: 0.6988
# Epoch 25/75
# 16784/16784 [==============================] - 2s 95us/step - loss: 0.5951 - acc: 0.6532 - precision: 0.6359 - recall: 0.7142 - auroc: 0.7269 - val_loss: 0.6150 - val_acc: 0.6109 - val_precision: 0.3579 - val_recall: 0.6821 - val_auroc: 0.6987
# Epoch 26/75
# 16784/16784 [==============================] - 2s 98us/step - loss: 0.5959 - acc: 0.6534 - precision: 0.6365 - recall: 0.7163 - auroc: 0.7266 - val_loss: 0.6168 - val_acc: 0.6099 - val_precision: 0.3589 - val_recall: 0.6905 - val_auroc: 0.6990
# Epoch 27/75
# 16784/16784 [==============================] - 2s 102us/step - loss: 0.5945 - acc: 0.6560 - precision: 0.6396 - recall: 0.7178 - auroc: 0.7296 - val_loss: 0.6150 - val_acc: 0.6116 - val_precision: 0.3586 - val_recall: 0.6823 - val_auroc: 0.6989
# Epoch 28/75
# 16784/16784 [==============================] - 2s 99us/step - loss: 0.5955 - acc: 0.6529 - precision: 0.6386 - recall: 0.7115 - auroc: 0.7264 - val_loss: 0.6160 - val_acc: 0.6099 - val_precision: 0.3578 - val_recall: 0.6857 - val_auroc: 0.6989
# Epoch 29/75
# 16784/16784 [==============================] - 2s 93us/step - loss: 0.5956 - acc: 0.6551 - precision: 0.6391 - recall: 0.7181 - auroc: 0.7295 - val_loss: 0.6184 - val_acc: 0.6091 - val_precision: 0.3589 - val_recall: 0.6950 - val_auroc: 0.6989
# Epoch 30/75
# 16784/16784 [==============================] - 2s 90us/step - loss: 0.5943 - acc: 0.6541 - precision: 0.6377 - recall: 0.7179 - auroc: 0.7285 - val_loss: 0.6173 - val_acc: 0.6104 - val_precision: 0.3587 - val_recall: 0.6890 - val_auroc: 0.6995
# Epoch 31/75
# 16784/16784 [==============================] - 2s 98us/step - loss: 0.5955 - acc: 0.6546 - precision: 0.6360 - recall: 0.7174 - auroc: 0.7232 - val_loss: 0.6172 - val_acc: 0.6104 - val_precision: 0.3588 - val_recall: 0.6890 - val_auroc: 0.6993
# Epoch 32/75
# 16784/16784 [==============================] - 2s 99us/step - loss: 0.5953 - acc: 0.6519 - precision: 0.6351 - recall: 0.7133 - auroc: 0.7270 - val_loss: 0.6149 - val_acc: 0.6114 - val_precision: 0.3583 - val_recall: 0.6820 - val_auroc: 0.6988
# Epoch 33/75
# 16784/16784 [==============================] - 2s 98us/step - loss: 0.5938 - acc: 0.6543 - precision: 0.6375 - recall: 0.7101 - auroc: 0.7277 - val_loss: 0.6155 - val_acc: 0.6111 - val_precision: 0.3585 - val_recall: 0.6830 - val_auroc: 0.6988
# Epoch 34/75
# 16784/16784 [==============================] - 2s 93us/step - loss: 0.5955 - acc: 0.6535 - precision: 0.6371 - recall: 0.7124 - auroc: 0.7268 - val_loss: 0.6158 - val_acc: 0.6109 - val_precision: 0.3582 - val_recall: 0.6823 - val_auroc: 0.6987
# Epoch 35/75
# 16784/16784 [==============================] - 2s 96us/step - loss: 0.5945 - acc: 0.6538 - precision: 0.6384 - recall: 0.7155 - auroc: 0.7277 - val_loss: 0.6149 - val_acc: 0.6126 - val_precision: 0.3587 - val_recall: 0.6784 - val_auroc: 0.6990
# Epoch 36/75
# 16784/16784 [==============================] - 2s 99us/step - loss: 0.5939 - acc: 0.6566 - precision: 0.6399 - recall: 0.7158 - auroc: 0.7273 - val_loss: 0.6177 - val_acc: 0.6106 - val_precision: 0.3589 - val_recall: 0.6875 - val_auroc: 0.6990
# Epoch 37/75
# 16784/16784 [==============================] - 2s 105us/step - loss: 0.5943 - acc: 0.6532 - precision: 0.6386 - recall: 0.7083 - auroc: 0.7298 - val_loss: 0.6168 - val_acc: 0.6114 - val_precision: 0.3587 - val_recall: 0.6826 - val_auroc: 0.6983
# Epoch 38/75
# 16784/16784 [==============================] - 2s 98us/step - loss: 0.5954 - acc: 0.6537 - precision: 0.6375 - recall: 0.7116 - auroc: 0.7259 - val_loss: 0.6165 - val_acc: 0.6119 - val_precision: 0.3593 - val_recall: 0.6858 - val_auroc: 0.6984
# Epoch 39/75
# 16784/16784 [==============================] - 3s 150us/step - loss: 0.5950 - acc: 0.6512 - precision: 0.6360 - recall: 0.7083 - auroc: 0.7263 - val_loss: 0.6191 - val_acc: 0.6089 - val_precision: 0.3584 - val_recall: 0.6923 - val_auroc: 0.6993
# Epoch 40/75
# 16784/16784 [==============================] - 2s 104us/step - loss: 0.5939 - acc: 0.6540 - precision: 0.6388 - recall: 0.7143 - auroc: 0.7277 - val_loss: 0.6171 - val_acc: 0.6106 - val_precision: 0.3589 - val_recall: 0.6874 - val_auroc: 0.6984
# Epoch 41/75
# 16784/16784 [==============================] - 2s 105us/step - loss: 0.5941 - acc: 0.6529 - precision: 0.6351 - recall: 0.7167 - auroc: 0.7270 - val_loss: 0.6159 - val_acc: 0.6116 - val_precision: 0.3593 - val_recall: 0.6852 - val_auroc: 0.6988
# Epoch 42/75
# 16784/16784 [==============================] - 2s 109us/step - loss: 0.5945 - acc: 0.6546 - precision: 0.6381 - recall: 0.7131 - auroc: 0.7288 - val_loss: 0.6148 - val_acc: 0.6131 - val_precision: 0.3601 - val_recall: 0.6836 - val_auroc: 0.6988
# Epoch 43/75
# 15712/16784 [===========================>..] - ETA: 0s - loss: 0.5933 - acc: 0.6557 - precision: 0.6388 - recall: 0.7137 - auroc: 0.7291

# %%
# Graph Metrics
graph_metrics = list(history[0].history.keys())
graph_metrics

# %%
# Graphs
no_of_graphs = int(len(graph_metrics)/2)

count = 0
foldcount = 0
for hist in history:
    print("K-Fold " + str(foldcount))
    f, axes = plt.subplots(no_of_graphs, 1, figsize=(16, 14))
    
    for i in range(no_of_graphs):
        f.suptitle("K-Fold " + str(foldcount), fontsize=16)
        
        axes[i].set_title(graph_metrics[i])
        axes[i].plot(hist.history[graph_metrics[i]], label='Train')
        axes[i].plot(hist.history[graph_metrics[i+no_of_graphs]], label='Test')
        axes[i].legend()
        count+=1    
    for i in axes:
        i.set_xticks(range(0,epochs+1,5))
    
    count = 0
    foldcount+=1

# %% [markdown]
# # Confusion Matrix

# %%
# Function to combine array of Confusion Matrixes
def combine_CM(array_of_CM):
    combine = [tn, fp, fn, tp] = [0, 0, 0, 0]
    
    for CM in array_of_CM:
        count=0
        for value in CM.ravel():
            combine[count] += value
            count+=1

    result_array = np.array([[combine[0], combine[1]],
                             [combine[2], combine[3]]])
    return result_array

# %%
from sklearn.metrics import confusion_matrix

plt.figure(figsize = (25,50))
f, axes = plt.subplots(1, 2, figsize=(12, 4))
sns.heatmap(combine_CM(TrainSet_ConfusionMatrix),
           annot = True, fmt=".0f", annot_kws={"size": 18}, ax = axes[0])
sns.heatmap(combine_CM(TestSet_ConfusionMatrix), 
           annot = True, fmt=".0f", annot_kws={"size": 18}, ax = axes[1])
axes[0].set_title("Confusion Matrix of Train Set (" + str(combine_CM(TrainSet_ConfusionMatrix).ravel().sum()) + " Results)",
                 fontsize=15)
axes[1].set_title("Confusion Matrix of Test Set (" + str(combine_CM(TestSet_ConfusionMatrix).ravel().sum()) + " Results)",
                 fontsize=15);

# %% [markdown]
# <img src="Images/ConfusionMatrix_Eg.png">
#
# (Credits: https://cdn-images-1.medium.com/max/1600/1*Z54JgbS4DUwWSknhDCvNTQ.png)

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import auc

mean_auc_score = np.mean(auc_score)
print("Mean AUC-ROC score is %.4f" % mean_auc_score)

plt.figure(1)
plt.plot([0, 1], [0, 1], 'k--')

count=0
for i in range(len(auc_score)):
    plt.plot(fpr_and_tpr[i][0], fpr_and_tpr[i][1], label='Model (area = {:.3f})'.format(auc_score[i]))
    plt.xlabel('False positive rate')
    plt.ylabel('True positive rate (Sensitivity/Recall)')
    plt.title('ROC curve')
    plt.legend(loc='best')
plt.show()

# %%
# Zoom in view of the upper left corner.
plt.figure(2)
plt.xlim(0, 0.5)
plt.ylim(0.5, 1)
plt.plot([0, 1], [0, 1], 'k--')

for i in range(len(auc_score)):
    plt.plot(fpr_and_tpr[i][0], fpr_and_tpr[i][1], label='Model (area = {:.3f})'.format(auc_score[i]))
    plt.xlabel('False positive rate')
    plt.ylabel('True positive rate (Sensitivity/Recall)')
    plt.title('ROC curve (zoomed in at top left)')
    plt.legend(loc='best')
plt.show()

# %%
classifier.save("train_model_ver1.h5")
print("Saved model to disk")

# %% [markdown]
# _______________________________________________________________________________________________________________________________
# ## Load Model, only follows result of the last fold

# %%
# Computed with improved Engineered Features
loaded_model = load_model("train_model_ver1.h5", custom_objects={'auroc':auroc, 'precision':precision, 'recall':recall})
print("Model loaded from disk")

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import auc

y_train_pred_raw = loaded_model.predict(X_train)
y_train_pred = y_train_pred_raw>0.5
y_test_pred_raw = loaded_model.predict(X_test)
y_test_pred = y_pred_model>0.5

fpr_model, tpr_model, thresholds_model = roc_curve(y_test, y_test_pred_raw.ravel())
auc_model = auc(fpr_model, tpr_model)

# print(y_pred_model, '\n')
# print(fpr_model)
# print(tpr_model) 
# print(thresholds_model, '\n')
print(auc_model, '\n')

from sklearn.metrics import confusion_matrix

plt.figure(figsize = (25,50))
f, axes = plt.subplots(1, 2, figsize=(12, 4))
sns.heatmap(confusion_matrix(y_train, y_train_pred),
           annot = True, fmt=".0f", annot_kws={"size": 18}, ax = axes[0])
sns.heatmap(confusion_matrix(y_test, y_test_pred), 
           annot = True, fmt=".0f", annot_kws={"size": 18}, ax = axes[1])
axes[0].set_title("Confusion Matrix of Train Set")
axes[1].set_title("Confusion Matrix of Test Set")

# %% [markdown]
# <img src="Images/ConfusionMatrix_Eg.png">
#
# (Credits: https://cdn-images-1.medium.com/max/1600/1*Z54JgbS4DUwWSknhDCvNTQ.png)

# %%
plt.figure(1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_model, tpr_model, label='Model (area = {:.3f})'.format(auc_model))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate (Sensitivity/Recall)')
plt.title('ROC curve')
plt.legend(loc='best')
plt.show()

# %%
# Zoom in view of the upper left corner.
plt.figure(2)
plt.xlim(0, 0.5)
plt.ylim(0.5, 1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_model, tpr_model, label='Model (area = {:.3f})'.format(auc_model))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate (Sensitivity/Recall)')
plt.title('ROC curve (zoomed in at top left)')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ## Executive Summary:
# With this model, I hope to detect dangerous driving in real-time and prevent more of such incidents. This is especially relevant with the advent of autonomous vehicles.
# For example, if an autonomous vehicle detects that the driver under substance abuse is driving dangerously, it can pull over and prevent accidents.
#
# ## Future Work:
# Given the multi-faceted factors that contribute to dangerous driving, the current analysis is limited. In order to build a model that is able to detect in real-time or even before a dangerous driving incident occurs, more data and prediction methods should be explored (E.g. Using Computer Vision to analyse Traffic Data). The combination of these techniques will help yield a more accurate prediction.
